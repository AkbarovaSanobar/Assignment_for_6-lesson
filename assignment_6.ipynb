# %%
#https://ourworldindata.org/explorers/food-prices?facet=none&country=NGA~BGD~IND~ETH~MEX~USA~BRA~GBR&Diet=Nutritionally+adequate&Cost+or+Affordability=Cost+&Affordability+metric=Share+that+cannot+afford&Cost+metric=%25+of+average+food+expenditure

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style
import matplotlib as mpl
import matplotlib.animation as pltan
import plotly.express as px

# %%
ann = pd.read_csv('real-commodity-price-index-food-products.csv')
ann
# Out:
#     Entity      Code  Year      Cocoa      Coffee         Tea       Sugar  \
# 0    World  OWID_WRL  1850  79.912101  138.990669  191.122176  210.842593
# 1    World  OWID_WRL  1851  78.668958  120.275422  182.445759  224.011008
# 2    World  OWID_WRL  1852  63.192990  112.380173  155.164151  196.047017
# 3    World  OWID_WRL  1853  92.880480  115.685472  193.163534  221.618367
# 4    World  OWID_WRL  1854  94.584369  123.175183  180.652681  196.078431
# ..     ...       ...   ...        ...         ...         ...         ...
# 161  World  OWID_WRL  2011  30.950856  104.633987   33.092175   34.758403
# 162  World  OWID_WRL  2012  24.339000   70.519447   32.169401   28.216065
# 163  World  OWID_WRL  2013  24.449543   51.984920   31.300000   22.830000
# 164  World  OWID_WRL  2014  30.470000   74.140000   29.530000   21.790000
# 165  World  OWID_WRL  2015  30.967121   58.715669   29.174600   17.087190
#
#           Wheat         Rye        Rice        Corn      Barley        Beef  \
# ...

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
x = ann.Year
y = ann.Cocoa
z = ann.Coffee
v = ann.Tea
plt.style.use('seaborn-darkgrid')
plt.plot(x, y, color = "red")
plt.plot(x, z, color = 'green')
plt.plot(x, v, color = 'yellow')
plt.legend(['Cocoa', 'Coffee', 'Tea'], loc="center", bbox_to_anchor=(1.3, 0.7), shadow=True, ncol=1)

plt.xlabel('year', fontdict = font2)
plt.ylabel('Price index', fontdict = font2)
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid()
plt.title("Price index of brewed drinks 1850-2015", color = 'blue', fontdict = font1, loc = 'center')
plt.figsize=(25, 20)
plt.show()

# %%
plt.style.use('seaborn-darkgrid')
#plt.style.use('bmh')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title('Real commodity price index of grains during 1850-2015', color='blue')
plt.ylabel('price index', color='red')
plt.xlabel('grains', color='red')

labels = ['Wheat', 'Rye', 'Rice', 'Corn', 'Barley']
plt.boxplot([ann.Wheat, ann.Rye, ann.Rice, ann.Corn, ann.Barley], labels = labels)

plt.grid()
plt.show()

# %%
ann[['Beef', 'Lamb', 'Pork']]
# Out:
#            Beef        Lamb        Pork
# 0     78.465394   81.923191   76.308440
# 1     99.576322   88.173824   80.963846
# 2     98.587971   90.722126   88.149572
# 3    100.992556   95.857341  101.242744
# 4     95.316159   88.854047   66.823633
# ..          ...         ...         ...
# 154  195.682011  199.901823   18.957462
# 155  196.471582  179.915106   17.266451
# 156  190.347418  164.486798   17.782412
# 157  229.492089  184.540000   20.960000
# 158  203.667366  149.682263   13.747636
#
# [159 rows x 3 columns]

# %%
ann1 = ann[['Beef', 'Lamb', 'Pork']].describe()
ann1
# Out:
#              Beef        Lamb        Pork
# count  159.000000  159.000000  159.000000
# mean   146.994600  111.074753   70.352717
# std     90.125512   43.565351   36.866826
# min     53.508927   33.215755   12.448046
# 25%     86.528074   83.674785   46.309795
# 50%    108.606137   99.273388   68.107105
# 75%    183.181855  138.018098   93.292869
# max    492.634101  237.030937  197.299714

# %%
plt.style.use('dark_background')
my_plot = ann1.plot(kind='bar')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'yellow','size':15}
plt.xlabel('statistic numbers', fontdict = font2)
plt.ylabel('price index', fontdict = font2)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.3, 0.7), shadow=True, ncol=1)
plt.title('Real commodity price index of meats during 1850-2015', color='blue')
# Out:
# Text(0.5, 1.0, 'Real commodity price index of meats during 1850-2015')
